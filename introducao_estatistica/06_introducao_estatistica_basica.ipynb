# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Séries temporais
#
# ## Exemplo 1

# %%
x = np.linspace(0, 5, 100)
y = np.cos(np.pi * x)

plt.figure()
plt.plot(x, y, 'k')

# %% [markdown]
# ## Exemplo 2

# %%
x = np.linspace(0, 5, 100)
y = np.exp(-x) * np.cos(2*np.pi*x)

plt.figure()
plt.plot(x, y, 'k')

# %% [markdown]
# ## Exemplo 3

# %%
x = np.linspace(0, 5, 100)
y = np.exp(-x) * np.cos(2*np.pi*x)

plt.figure()
plt.plot(x, y, 'k')

# %% [markdown]
# ## Exemplo 4

# %%
g = 9.806
v0 = 33.22
y0 = 25.33

x = np.linspace(0, 7, 50)
y = y0 + v0 * x - 0.5 * g * x**2

plt.figure()
plt.plot(x, y, 'k')

# %% [markdown]
# ## Criando uma função

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# ## Gerando distribuição uniforme

# %%
np.random.uniform(low = -15, high = 15, size = 10)
# Out:
# array([11.7638567 ,  6.19234907, -2.20975652, 11.4041968 , 14.14536853,
#        -8.13027299, -6.87057965,  2.75362771, -8.26907077, -2.04466469])

# %% [markdown]
# # Simulando indicadores de saúde
#
# ## Função que gera o indicador

# %%
def time_series(max, n, a, b, c, date_start):
    stop = int((max - b)/a)
    x = np.linspace(0, stop, n)
    y = a * x + b + c * np.random.uniform(low = -15, high = 15, size = n) # np.random.normal(0,1,n)
    
    df_test = pd.DataFrame(y,columns=['name']).reset_index(drop=True)
    df_test['date'] = pd.date_range(start = date_start, periods = n)
    
    fig, ax = plt.subplots()
    ax.plot(x, y, label = "Data")
    return df_test

# %% [markdown]
# ## Idade em anos

# %%
df_age = time_series(
31,      # maximum value for the time series
350,        # number of sample size
-1,           # angular coefficient for the linear function
35,    # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2019'    # date to start with
)
df_age.rename(columns={'name': 'age_years'}, inplace=True)

# %% [markdown]
# ## IMC (Kg/m2)

# %%
df_bmi = time_series(
23,           # maximum value for the time series
350,          # number of sample size
-1,           # angular coefficient for the linear function
29,           # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2018'    # date to start with
)
df_bmi.rename(columns={'name': 'bmi_kg_m2'}, inplace=True)

# %% [markdown]
# ## Altura em cm

# %%
############################################## height_cm ##################################################
df_height = time_series(
177,      # maximum value for the time series
350,        # number of sample size
-1,           # angular coefficient for the linear function
175,    # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2018'    # date to start with
)
df_height.rename(columns={'name': 'height_cm'}, inplace=True)

# %% [markdown]
# ## Peso em kg

# %%
############################################## weight_kg ##################################################
df_weight = time_series(
73,      # maximum value for the time series
350,        # number of sample size
-1,           # angular coefficient for the linear function
80,    # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2018'    # date to start with
)
df_weight.rename(columns={'name': 'weight_kg'}, inplace=True)

# %% [markdown]
# ## HDL em mg/dl

# %%
############################################## hdl_mg_dl ##################################################
df_hdl = time_series(
70,      # maximum value for the time series
350,        # number of sample size
-1,           # angular coefficient for the linear function
40,    # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2018'    # date to start with
)
df_hdl.rename(columns={'name': 'hdl_mg_dl'}, inplace=True)

# %% [markdown]
# ## LDL em mg/dl

# %%
############################################## ldl_mg_dl ##################################################
df_ldl = time_series(
130,      # maximum value for the time series
350,        # number of sample size
-1,           # angular coefficient for the linear function
170,    # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2018'    # date to start with
)
df_ldl.rename(columns={'name': 'ldl_mg_dl'}, inplace=True)

# %% [markdown]
# ## Não HDL em mg/dl

# %%
############################################## non_hdl_mg_dl ##################################################
df_nonhdl = time_series(
130,      # maximum value for the time series
350,        # number of sample size
-1,           # angular coefficient for the linear function
150,    # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2018'    # date to start with
)
df_nonhdl.rename(columns={'name': 'non_hdl_mg_dl'}, inplace=True)

# %% [markdown]
# ## Colesterol total em mg/dl

# %%
############################################## total_cholesterol_mg_dl ##################################################
df_total_cholesterol = time_series(
190,      # maximum value for the time series
350,        # number of sample size
-1,           # angular coefficient for the linear function
250,    # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2018'    # date to start with
)
df_total_cholesterol.rename(columns={'name': 'total_cholesterol_mg_dl'}, inplace=True)

# %% [markdown]
# ## Triglicerideos em mg/dl

# %%
############################################## trygliceride_mg_dl ##################################################
df_trygliceride = time_series(
180,      # maximum value for the time series
350,        # number of sample size
-1,           # angular coefficient for the linear function
250,    # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2018'    # date to start with
)
df_trygliceride.rename(columns={'name': 'trygliceride_mg_dl'}, inplace=True)

# %% [markdown]
# ## Glicemia em jejum mg/dl

# %%
############################################## fast_blood_sugar_mg_dl ##################################################
df_fast_blood_sugar = time_series(
99,      # maximum value for the time series
350,        # number of sample size
-1,           # angular coefficient for the linear function
123,    # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2018'    # date to start with
)
df_fast_blood_sugar.rename(columns={'name': 'fast_blood_sugar_mg_dl'}, inplace=True)

# %% [markdown]
# ## Pressão sistólica mm hg

# %%
############################################## systolic_bp_mm_hg ##################################################
df_systolic_bp = time_series(
115,      # maximum value for the time series
350,        # number of sample size
-1,           # angular coefficient for the linear function
130,    # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2018'    # date to start with
)
df_systolic_bp.rename(columns={'name': 'systolic_bp_mm_hg'}, inplace=True)

# %% [markdown]
# ## Pressão diastólica mm hg

# %%
############################################## diastolic_bp_mm_hg ##################################################
df_diastolic_bp = time_series(
80,      # maximum value for the time series
350,        # number of sample size
-1,           # angular coefficient for the linear function
89,    # intercept for the linear function
0.1,         # value that multiplies the white noise
'1/1/2018'    # date to start with
)
df_diastolic_bp.rename(columns={'name': 'diastolic_bp_mm_hg'}, inplace=True)

# %% [markdown]
# # Criando dataframe

# %%
df_full_series = pd.DataFrame()
df_full_series['date'] = df_age['date']
df_full_series['age_years'] = df_age['age_years']
df_full_series['bmi_kg_m2'] = df_bmi['bmi_kg_m2']
df_full_series['height_cm'] = df_height['height_cm']
df_full_series['weight_kg'] = df_weight['weight_kg']
df_full_series['hdl_mg_dl'] = df_hdl['hdl_mg_dl']
df_full_series['ldl_mg_dl'] = df_ldl['ldl_mg_dl']
df_full_series['non_hdl_mg_dl'] = df_nonhdl['non_hdl_mg_dl']
df_full_series['total_cholesterol_mg_dl'] = df_total_cholesterol['total_cholesterol_mg_dl']
df_full_series['trygliceride_mg_dl'] = df_trygliceride['trygliceride_mg_dl']
df_full_series['fast_blood_sugar_mg_dl'] = df_fast_blood_sugar['fast_blood_sugar_mg_dl']
df_full_series['systolic_bp_mm_hg'] = df_systolic_bp['systolic_bp_mm_hg']
df_full_series['diastolic_bp_mm_hg'] = df_diastolic_bp['diastolic_bp_mm_hg']
df_full_series;

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 10))

df_full_series.plot(x = 'date', y = ['bmi_kg_m2'], style='-', color = 'lightblue', ax = axes[0,0])
df_full_series.plot(x = 'date', y = ['hdl_mg_dl'], style='-', color = 'red', ax = axes[0,1])
df_full_series.plot(x = 'date', y = ['ldl_mg_dl'], style='-', color = 'green', ax = axes[0,2])

df_full_series.plot(x = 'date', y = ['non_hdl_mg_dl'], style='-', color = 'orange', ax = axes[1,0])
df_full_series.plot(x = 'date', y = ['total_cholesterol_mg_dl'], style='-', color = 'coral', ax = axes[1,1])
df_full_series.plot(x = 'date', y = ['trygliceride_mg_dl'], style='-', color = 'tomato', ax = axes[1,2])

df_full_series.plot(x = 'date', y = ['fast_blood_sugar_mg_dl'], style='-', color = 'grey', ax = axes[2,0])
df_full_series.plot(x = 'date', y = ['systolic_bp_mm_hg'], style='-', color = 'black', ax = axes[2,1])
df_full_series.plot(x = 'date', y = ['diastolic_bp_mm_hg'], style='-', color = 'navy', ax = axes[2,2])
# Out:
# <AxesSubplot:xlabel='date'>
