# %% [markdown]
# # Função (dataset sintético)

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# define a função que gera o dataset sintético
def gerar_dataset_sintetico(n=200, seed=42):
    # fixa a semente para reprodutibilidade
    np.random.seed(seed)
    # lista completa de UFs brasileiras
    ufs = ["AC","AL","AP","AM","BA","CE","DF","ES","GO","MA","MT","MS","MG","PA","PB",
           "PR","PE","PI","RJ","RN","RS","RO","RR","SC","SP","SE","TO"]
    # define a data atual como referência
    hoje = datetime.today()
    # gera datas de nascimento aleatórias entre 18 e 40 anos
    datas_nascimento = [hoje - timedelta(days=int(365 * np.random.uniform(18, 40))) for _ in range(n)]
    # cria o DataFrame principal
    df = pd.DataFrame({
        # cria um identificador único incremental
        "id": range(1, n + 1),
        # gera sexo aleatório
        "sexo": np.random.choice(["M", "F"], size=n),
        # gera estados aleatórios
        "uf": np.random.choice(ufs, size=n),
        # atribui datas de nascimento
        "data_nascimento": datas_nascimento,
        # gera notas de matemática com distribuição normal truncada
        "nota_matematica": np.random.normal(6.5, 1.5, n).clip(0, 10),
        # gera notas de física com distribuição normal truncada
        "nota_fisica": np.random.normal(7.5, 2.7, n).clip(0, 10),
        # gera notas de química com distribuição normal truncada
        "nota_quimica": np.random.normal(6.5, 1.6, n).clip(0, 10),
        # gera notas de inglês com distribuição normal truncada
        "nota_ingles": np.random.normal(7.0, 1.2, n).clip(0, 10),
        # gera notas de português com distribuição normal truncada
        "nota_portugues": np.random.normal(6.8, 1.3, n).clip(0, 10),
        # gera quantidade de filhos como inteiro (Poisson)
        "quantidade_filhos": np.random.poisson(lam=1.2, size=n).astype(int)
    })
    # calcula a idade aproximada a partir da data de nascimento
    df["idade"] = df["data_nascimento"].apply(lambda x: (hoje - x).days // 365)
    # força zero filhos para menores de 18 anos
    df.loc[df["idade"] < 18, "quantidade_filhos"] = 0
    # retorna o DataFrame final
    return df

# %% [markdown]
# # Gera o dataset sintético

# %%
# gera o dataset sintético
df = gerar_dataset_sintetico(n=20000)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 20000 non-null  int64
#  1   sexo               20000 non-null  object
#  2   uf                 20000 non-null  object
#  3   data_nascimento    20000 non-null  datetime64[ns]
#  4   nota_matematica    20000 non-null  float64
#  5   nota_fisica        20000 non-null  float64
#  6   nota_quimica       20000 non-null  float64
#  7   nota_ingles        20000 non-null  float64
#  8   nota_portugues     20000 non-null  float64
#  9   quantidade_filhos  20000 non-null  int32
#  10  idade              20000 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(2), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# # Comandos Python
#
# ✔️ import pandas as pd
# ✔️ pd.read_csv()
# ✔️ df.head()
# ✔️ df.tail()
# ✔️ df.info()
# ✔️ df.describe()
# ✔️ df['coluna']
# ✔️ df[df['coluna'] > x]
# ✔️ df.groupby()
# ✔️ df.sort_values()
# ✔️ df.isnull().sum()
# ✔️ df.fillna()
# ✔️ df.dropna()

# %% [markdown]
# ## Head

# %%
# exibe as primeiras linhas do dataset
df.head()
# Out:
#    id sexo  uf            data_nascimento  nota_matematica  nota_fisica  \
# 0   1    F  MG 1999-10-18 20:55:09.356234         4.319503     8.195804
# 1   2    F  TO 1987-02-16 20:55:09.356234         4.991319    10.000000
# 2   3    F  CE 1991-12-09 20:55:09.356234         8.338124     1.877807
# 3   4    M  AC 1994-11-13 20:55:09.356234         5.716371    10.000000
# 4   5    M  CE 2004-08-07 20:55:09.356234         7.472725     7.556392
#
#    nota_quimica  nota_ingles  nota_portugues  quantidade_filhos  idade
# 0      8.393607     7.179562        8.212824                  1     26
# 1      6.645519     7.115570        9.332715                  0     38
# 2      8.809046     7.954536        7.564541                  0     34
# 3      6.003478     6.934793        6.156080                  1     31
# 4      6.120767     6.593623        8.568878                  2     21

# %% [markdown]
# ## Tail

# %%
# exibe as últimas linhas do dataset
df.tail()
# Out:
#           id sexo  uf            data_nascimento  nota_matematica  \
# 19995  19996    M  AM 1988-09-30 20:55:09.356234         3.672413
# 19996  19997    M  RJ 2007-01-01 20:55:09.356234         6.119708
# 19997  19998    F  AL 2001-05-09 20:55:09.356234         8.268505
# 19998  19999    M  MT 1998-04-14 20:55:09.356234         5.902699
# 19999  20000    M  MT 2004-03-29 20:55:09.356234         6.761171
#
#        nota_fisica  nota_quimica  nota_ingles  nota_portugues  \
# 19995     7.213874      6.959902     7.839001        7.920293
# 19996     4.745181      5.486606     6.302505        7.881138
# 19997     5.093781      6.446561     6.794381        5.725462
# 19998     8.181471      7.228378     6.018716        5.006354
# 19999     3.436367      8.014234     7.232908        5.990048
#
#        quantidade_filhos  idade
# 19995                  1     37
# 19996                  0     19
# 19997                  1     24
# 19998                  1     27
# 19999                  1     21

# %% [markdown]
# ## Info

# %%
# mostra tipos, memória e valores nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 20000 non-null  int64
#  1   sexo               20000 non-null  object
#  2   uf                 20000 non-null  object
#  3   data_nascimento    20000 non-null  datetime64[ns]
#  4   nota_matematica    20000 non-null  float64
#  5   nota_fisica        20000 non-null  float64
#  6   nota_quimica       20000 non-null  float64
#  7   nota_ingles        20000 non-null  float64
#  8   nota_portugues     20000 non-null  float64
#  9   quantidade_filhos  20000 non-null  int32
#  10  idade              20000 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int32(1), int64(2), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Describe

# %%
# apresenta estatísticas descritivas das colunas numéricas
df.describe()
# Out:
#                  id  nota_matematica   nota_fisica  nota_quimica  \
# count  20000.000000     20000.000000  20000.000000  20000.000000
# mean   10000.500000         6.500439      7.227739      6.497660
# std     5773.647028         1.491230      2.283213      1.598194
# min        1.000000         0.557631      0.000000      0.545875
# 25%     5000.750000         5.500341      5.672525      5.397442
# 50%    10000.500000         6.501285      7.459497      6.509872
# 75%    15000.250000         7.522477      9.292931      7.591178
# max    20000.000000        10.000000     10.000000     10.000000
#
#         nota_ingles  nota_portugues  quantidade_filhos         idade
# count  20000.000000    20000.000000       20000.000000  20000.000000
# mean       6.995439        6.812076           1.190450     28.483900
# std        1.192807        1.278964           1.094184      6.339105
# min        2.453559        1.341846           0.000000     18.000000
# 25%        6.193615        5.944982           0.000000     23.000000
# 50%        6.987128        6.815183           1.000000     28.000000
# 75%        7.804888        7.684990           2.000000     34.000000
# max       10.000000       10.000000           7.000000     39.000000

# %% [markdown]
# ## df[nome_coluna]

# %%
# seleciona uma única coluna
df["uf"]
# Out:
# 0        MG
# 1        TO
# 2        CE
# 3        AC
# 4        CE
#          ..
# 19995    AM
# 19996    RJ
# 19997    AL
# 19998    MT
# 19999    MT
# Name: uf, Length: 20000, dtype: object

# %% [markdown]
# ## Filtro lógico com nome_coluna

# %%
# filtra registros com idade maior que 25
df[df["idade"] > 25]
# Out:
#           id sexo  uf            data_nascimento  nota_matematica  \
# 0          1    F  MG 1999-10-18 20:55:09.356234         4.319503
# 1          2    F  TO 1987-02-16 20:55:09.356234         4.991319
# 2          3    F  CE 1991-12-09 20:55:09.356234         8.338124
# 3          4    M  AC 1994-11-13 20:55:09.356234         5.716371
# 7          8    M  MG 1988-12-26 20:55:09.356234         8.456707
# ...      ...  ...  ..                        ...              ...
# 19991  19992    M  PE 1991-05-03 20:55:09.356234         7.003758
# 19993  19994    M  AC 1997-03-13 20:55:09.356234         5.865017
# 19994  19995    M  AP 1988-03-21 20:55:09.356234         4.934196
# 19995  19996    M  AM 1988-09-30 20:55:09.356234         3.672413
# 19998  19999    M  MT 1998-04-14 20:55:09.356234         5.902699
#
#        nota_fisica  nota_quimica  nota_ingles  nota_portugues  \
# 0         8.195804      8.393607     7.179562        8.212824
# 1        10.000000      6.645519     7.115570        9.332715
# 2         1.877807      8.809046     7.954536        7.564541
# 3        10.000000      6.003478     6.934793        6.156080
# 7         6.009883      6.340221     6.766094       10.000000
# ...            ...           ...          ...             ...
# 19991    10.000000      6.451853     7.667586        5.839237
# 19993    10.000000      6.214769     7.738497        5.714823
# 19994     7.859707      8.547665     4.923109        7.023684
# 19995     7.213874      6.959902     7.839001        7.920293
# 19998     8.181471      7.228378     6.018716        5.006354
#
#        quantidade_filhos  idade
# 0                      1     26
# 1                      0     38
# 2                      0     34
# 3                      1     31
# 7                      0     37
# ...                  ...    ...
# 19991                  1     34
# 19993                  0     28
# 19994                  1     37
# 19995                  1     37
# 19998                  1     27
#
# [12739 rows x 11 columns]

# %% [markdown]
# ## Group by com média

# %%
# agrupa por estado e calcula média de matemática
df.groupby("uf")["nota_matematica"].mean()
# Out:
# uf
# AC    6.486863
# AL    6.541370
# AM    6.473147
# AP    6.420040
# BA    6.561655
# CE    6.435255
# DF    6.508192
# ES    6.448317
# GO    6.552246
# MA    6.499946
# MG    6.487432
# MS    6.577173
# MT    6.491586
# PA    6.495201
# PB    6.556079
# PE    6.554649
# PI    6.483235
# PR    6.571731
# RJ    6.458164
# RN    6.530404
# RO    6.405598
# RR    6.466639
# RS    6.447631
# SC    6.531069
# SE    6.520465
# SP    6.446105
# TO    6.568517
# Name: nota_matematica, dtype: float64

# %% [markdown]
# ## Group by com mais de uma coluna e média

# %%
# agrupa por sexo e calcula médias de física e química
df.groupby("sexo")[["nota_fisica", "nota_quimica"]].mean()
# Out:
#       nota_fisica  nota_quimica
# sexo
# F        7.214400      6.511533
# M        7.240814      6.484062

# %% [markdown]
# ## Sort_values

# %%
# ordena os alunos pela nota de matemática
df.sort_values("nota_matematica", ascending=False)
# Out:
#           id sexo  uf            data_nascimento  nota_matematica  \
# 10390  10391    F  MA 1988-07-17 20:55:09.356234        10.000000
# 18203  18204    F  AL 1990-01-06 20:55:09.356234        10.000000
# 5078    5079    M  SC 1997-05-26 20:55:09.356234        10.000000
# 14715  14716    F  RS 2005-01-28 20:55:09.356234        10.000000
# 1260    1261    M  DF 2002-02-11 20:55:09.356234        10.000000
# ...      ...  ...  ..                        ...              ...
# 10780  10781    F  RJ 1986-12-11 20:55:09.356234         1.296625
# 12534  12535    F  ES 2004-09-29 20:55:09.356234         1.275847
# 19413  19414    M  SE 1999-12-10 20:55:09.356234         1.093406
# 6662    6663    F  AL 2000-05-28 20:55:09.356234         0.737111
# 5360    5361    F  AM 1994-10-07 20:55:09.356234         0.557631
#
#        nota_fisica  nota_quimica  nota_ingles  nota_portugues  \
# 10390     7.314368      7.045482     7.199648        5.077848
# 18203    10.000000      5.168422     5.240195        6.451523
# 5078      6.750254      5.955038     6.310790        8.540626
# 14715     9.632524      5.893209     6.643384        5.372331
# 1260      4.632468      7.702320     7.925740        4.161888
# ...            ...           ...          ...             ...
# 10780     9.084918      5.977501     5.912075        6.316310
# 12534     7.943028      8.389810     4.540847        6.727801
# 19413     6.836639      8.408188     6.787220        6.514450
# 6662      5.174326     10.000000     5.953883        9.255369
# 5360      6.229340      4.361917    10.000000        5.171436
#
#        quantidade_filhos  idade
# 10390                  2     37
# 18203                  0     36
# 5078                   2     28
# 14715                  1     20
# 1260                   2     23
# ...                  ...    ...
# 10780                  1     39
# 12534                  2     21
# 19413                  3     26
# 6662                   0     25
# 5360                   1     31
#
# [20000 rows x 11 columns]

# %% [markdown]
# ## Isnull() e sum()

# %%
# contabiliza valores nulos por coluna
df.isnull().sum()
# Out:
# id                   0
# sexo                 0
# uf                   0
# data_nascimento      0
# nota_matematica      0
# nota_fisica          0
# nota_quimica         0
# nota_ingles          0
# nota_portugues       0
# quantidade_filhos    0
# idade                0
# dtype: int64

# %% [markdown]
# ## Fillna

# %%
# substitui valores nulos por zero
df.fillna(0)
# Out:
#           id sexo  uf            data_nascimento  nota_matematica  \
# 0          1    F  MG 1999-10-18 20:55:09.356234         4.319503
# 1          2    F  TO 1987-02-16 20:55:09.356234         4.991319
# 2          3    F  CE 1991-12-09 20:55:09.356234         8.338124
# 3          4    M  AC 1994-11-13 20:55:09.356234         5.716371
# 4          5    M  CE 2004-08-07 20:55:09.356234         7.472725
# ...      ...  ...  ..                        ...              ...
# 19995  19996    M  AM 1988-09-30 20:55:09.356234         3.672413
# 19996  19997    M  RJ 2007-01-01 20:55:09.356234         6.119708
# 19997  19998    F  AL 2001-05-09 20:55:09.356234         8.268505
# 19998  19999    M  MT 1998-04-14 20:55:09.356234         5.902699
# 19999  20000    M  MT 2004-03-29 20:55:09.356234         6.761171
#
#        nota_fisica  nota_quimica  nota_ingles  nota_portugues  \
# 0         8.195804      8.393607     7.179562        8.212824
# 1        10.000000      6.645519     7.115570        9.332715
# 2         1.877807      8.809046     7.954536        7.564541
# 3        10.000000      6.003478     6.934793        6.156080
# 4         7.556392      6.120767     6.593623        8.568878
# ...            ...           ...          ...             ...
# 19995     7.213874      6.959902     7.839001        7.920293
# 19996     4.745181      5.486606     6.302505        7.881138
# 19997     5.093781      6.446561     6.794381        5.725462
# 19998     8.181471      7.228378     6.018716        5.006354
# 19999     3.436367      8.014234     7.232908        5.990048
#
#        quantidade_filhos  idade
# 0                      1     26
# 1                      0     38
# 2                      0     34
# 3                      1     31
# 4                      2     21
# ...                  ...    ...
# 19995                  1     37
# 19996                  0     19
# 19997                  1     24
# 19998                  1     27
# 19999                  1     21
#
# [20000 rows x 11 columns]

# %% [markdown]
# ## Dropna()

# %%
# remove linhas com qualquer valor nulo
df.dropna()
# Out:
#           id sexo  uf            data_nascimento  nota_matematica  \
# 0          1    F  MG 1999-10-18 20:55:09.356234         4.319503
# 1          2    F  TO 1987-02-16 20:55:09.356234         4.991319
# 2          3    F  CE 1991-12-09 20:55:09.356234         8.338124
# 3          4    M  AC 1994-11-13 20:55:09.356234         5.716371
# 4          5    M  CE 2004-08-07 20:55:09.356234         7.472725
# ...      ...  ...  ..                        ...              ...
# 19995  19996    M  AM 1988-09-30 20:55:09.356234         3.672413
# 19996  19997    M  RJ 2007-01-01 20:55:09.356234         6.119708
# 19997  19998    F  AL 2001-05-09 20:55:09.356234         8.268505
# 19998  19999    M  MT 1998-04-14 20:55:09.356234         5.902699
# 19999  20000    M  MT 2004-03-29 20:55:09.356234         6.761171
#
#        nota_fisica  nota_quimica  nota_ingles  nota_portugues  \
# 0         8.195804      8.393607     7.179562        8.212824
# 1        10.000000      6.645519     7.115570        9.332715
# 2         1.877807      8.809046     7.954536        7.564541
# 3        10.000000      6.003478     6.934793        6.156080
# 4         7.556392      6.120767     6.593623        8.568878
# ...            ...           ...          ...             ...
# 19995     7.213874      6.959902     7.839001        7.920293
# 19996     4.745181      5.486606     6.302505        7.881138
# 19997     5.093781      6.446561     6.794381        5.725462
# 19998     8.181471      7.228378     6.018716        5.006354
# 19999     3.436367      8.014234     7.232908        5.990048
#
#        quantidade_filhos  idade
# 0                      1     26
# 1                      0     38
# 2                      0     34
# 3                      1     31
# 4                      2     21
# ...                  ...    ...
# 19995                  1     37
# 19996                  0     19
# 19997                  1     24
# 19998                  1     27
# 19999                  1     21
#
# [20000 rows x 11 columns]

# %% [markdown]
# ## Criando arquivo parquet

# %%
df.to_parquet('df_fast_track.parquet')

# %% [markdown]
# ## Criando arquivo csv

# %%
df.to_csv('df_fast_track.csv', sep = ';', index = False)

# %% [markdown]
# ## Lendo arquivo csv

# %%
df_from_csv = pd.read_csv('df_fast_track.csv', sep = ',')
# df_from_csv.head()

# %% [markdown]
# # Comandos SQL (com duckdb)
# ✔️ SELECT
# ✔️ FROM
# ✔️ WHERE
# ✔️ ORDER BY
# ✔️ SUM()
# ✔️ COUNT()
# ✔️ AVG()
# ✔️ GROUP BY
# ✔️ CREATE
# ✔️ INSERT
# ✔️ DELETE

# %% [markdown]
# ## Importando o duckdb

# %%
# importa a biblioteca duckdb
import duckdb
# cria uma conexão em memória
con = duckdb.connect()
# registra o DataFrame como tabela SQL
con.register("alunos", df)

# %% [markdown]
# ## Select, from

# %%
# executa um SELECT com filtro por idade
con.execute("SELECT * FROM alunos WHERE idade > 25").df()
# Out:
#           id sexo  uf            data_nascimento  nota_matematica  \
# 0          1    F  MG 1999-10-18 20:55:09.356234         4.319503
# 1          2    F  TO 1987-02-16 20:55:09.356234         4.991319
# 2          3    F  CE 1991-12-09 20:55:09.356234         8.338124
# 3          4    M  AC 1994-11-13 20:55:09.356234         5.716371
# 4          8    M  MG 1988-12-26 20:55:09.356234         8.456707
# ...      ...  ...  ..                        ...              ...
# 12734  19992    M  PE 1991-05-03 20:55:09.356234         7.003758
# 12735  19994    M  AC 1997-03-13 20:55:09.356234         5.865017
# 12736  19995    M  AP 1988-03-21 20:55:09.356234         4.934196
# 12737  19996    M  AM 1988-09-30 20:55:09.356234         3.672413
# 12738  19999    M  MT 1998-04-14 20:55:09.356234         5.902699
#
#        nota_fisica  nota_quimica  nota_ingles  nota_portugues  \
# 0         8.195804      8.393607     7.179562        8.212824
# 1        10.000000      6.645519     7.115570        9.332715
# 2         1.877807      8.809046     7.954536        7.564541
# 3        10.000000      6.003478     6.934793        6.156080
# 4         6.009883      6.340221     6.766094       10.000000
# ...            ...           ...          ...             ...
# 12734    10.000000      6.451853     7.667586        5.839237
# 12735    10.000000      6.214769     7.738497        5.714823
# 12736     7.859707      8.547665     4.923109        7.023684
# 12737     7.213874      6.959902     7.839001        7.920293
# 12738     8.181471      7.228378     6.018716        5.006354
#
#        quantidade_filhos  idade
# 0                      1     26
# 1                      0     38
# 2                      0     34
# 3                      1     31
# 4                      0     37
# ...                  ...    ...
# 12734                  1     34
# 12735                  0     28
# 12736                  1     37
# 12737                  1     37
# 12738                  1     27
#
# [12739 rows x 11 columns]

# %% [markdown]
# ## From, group by, order by

# %%
# executa agregação com GROUP BY e ORDER BY
con.execute("""
SELECT
    uf,
    COUNT(*) AS total_alunos,
    AVG(nota_matematica) AS media_matematica
FROM alunos
GROUP BY uf
ORDER BY media_matematica DESC
""").df()
# Out:
#     uf  total_alunos  media_matematica
# 0   MS           723          6.577173
# 1   PR           711          6.571731
# 2   TO           736          6.568517
# 3   BA           722          6.561655
# 4   PB           721          6.556079
# 5   PE           749          6.554649
# 6   GO           739          6.552246
# 7   AL           759          6.541370
# 8   SC           750          6.531069
# 9   RN           737          6.530404
# 10  SE           800          6.520465
# 11  DF           751          6.508192
# 12  MA           770          6.499946
# 13  PA           692          6.495201
# 14  MT           709          6.491586
# 15  MG           748          6.487432
# 16  AC           695          6.486863
# 17  PI           717          6.483235
# 18  AM           792          6.473147
# 19  RR           802          6.466639
# 20  RJ           731          6.458164
# 21  ES           741          6.448317
# 22  RS           738          6.447631
# 23  SP           748          6.446105
# 24  CE           750          6.435255
# 25  AP           721          6.420040
# 26  RO           748          6.405598

# %% [markdown]
# ## Select, from, where

# %%
# seleciona registros com valores nulos em nota_fisica
con.execute("SELECT * FROM alunos WHERE nota_fisica IS NULL").df()
# Out:
# Empty DataFrame
# Columns: [id, sexo, uf, data_nascimento, nota_matematica, nota_fisica, nota_quimica, nota_ingles, nota_portugues, quantidade_filhos, idade]
# Index: []

# %% [markdown]
# ## Create table

# %%
# cria uma tabela física a partir do DataFrame
con.execute("CREATE TABLE alunos_sql AS SELECT * FROM alunos")

# %%
con.execute("DESCRIBE alunos_sql").fetchdf()
# Out:
#           column_name   column_type null   key default extra
# 0                  id        BIGINT  YES  None    None  None
# 1                sexo       VARCHAR  YES  None    None  None
# 2                  uf       VARCHAR  YES  None    None  None
# 3     data_nascimento  TIMESTAMP_NS  YES  None    None  None
# 4     nota_matematica        DOUBLE  YES  None    None  None
# 5         nota_fisica        DOUBLE  YES  None    None  None
# 6        nota_quimica        DOUBLE  YES  None    None  None
# 7         nota_ingles        DOUBLE  YES  None    None  None
# 8      nota_portugues        DOUBLE  YES  None    None  None
# 9   quantidade_filhos       INTEGER  YES  None    None  None
# 10              idade        BIGINT  YES  None    None  None

# %% [markdown]
# ## Insert

# %%
# insere um novo registro manualmente
con.execute("INSERT INTO alunos_sql VALUES (20001,'F','SP',DATE '2000-01-01',8.0,7.5,7.0,9.0,8.5,24,1)")

# %%
con.execute("SELECT * FROM alunos_sql where id = 20001").df()
# Out:
#       id sexo  uf data_nascimento  nota_matematica  nota_fisica  nota_quimica  \
# 0  20001    F  SP      2000-01-01              8.0          7.5           7.0
#
#    nota_ingles  nota_portugues  quantidade_filhos  idade
# 0          9.0             8.5                 24      1

# %% [markdown]
# ## Delete

# %%
# remove registros com nota de física nula
con.execute("DELETE FROM alunos_sql WHERE id = 20001")

# %%
con.execute("SELECT * FROM alunos_sql where id = 20001").df()
# Out:
# Empty DataFrame
# Columns: [id, sexo, uf, data_nascimento, nota_matematica, nota_fisica, nota_quimica, nota_ingles, nota_portugues, quantidade_filhos, idade]
# Index: []

# %% [markdown]
# # Funções do PowerBI
# ✔️ `SUM(coluna)`
# Soma todos os valores numéricos da coluna no contexto atual de filtro.
# ✔️ `COUNT(coluna)`
# Conta quantos valores não nulos existem na coluna, respeitando os filtros.
# ✔️ `DIVIDE(numerador, denominador)`
# Realiza divisão segura, evitando erro quando o denominador é zero.
# ✔️ `CALCULATE()`
# Recalcula uma métrica alterando o contexto de filtro. É a função central do DAX.
# ✔️ `FILTER()`
# Cria um filtro linha a linha com base em uma condição lógica.
# ✔️ `ALL()`
# Remove filtros de uma tabela ou coluna, permitindo cálculos globais.
# ✔️ `VALUES()`
# Retorna os valores distintos de uma coluna dentro do contexto atual.
# ✔️ `COUNTROWS()`
# Conta o número de linhas de uma tabela (física ou virtual).
# ✔️ `IF()`
# Avalia uma condição sobre métricas agregadas e retorna um valor conforme o resultado.
# ✔️ `SWITCH()`
# Avalia múltiplas condições sobre uma métrica agregada, substituindo vários IF encadeados.
# ✔️ `SUMX()`
# Avalia uma expressão linha a linha e soma os resultados obtidos.
# ✔️ `RELATED()`
# Busca um valor em uma tabela relacionada. Usado apenas em coluna calculada.
